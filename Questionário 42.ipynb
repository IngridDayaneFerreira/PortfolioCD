# %%
#Respostas

#Questão 1: Letra A
#Questão 2: Letra A
#Questão 3: Letra B

# %%
#Questão 1
import pandas as pd
import numpy as np

sudeste = pd.read_excel('enem2019.xlsx')
for i in range(sudeste['COD UF'].count()):
    if ((sudeste.loc[i]['COD UF'] // 10) != 3):
        sudeste = sudeste.drop([i], axis=0)
sudeste
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 18      33     RJ                    73086
# 22      32     ES                    25422
# 23      31     MG                   108173
# 24      35     SP                   219426
#
#     Total de inscritos de Ensino Médio Público  \
# 18                                       58065
# 22                                       23187
# 23                                       97493
# 24                                      185540
#
#     Total de inscritos de Ensino Médio Privado  \
# 18                                       15021
# 22                                        2235
# 23                                       10680
# 24                                       33886
#
#     Média da nota da prova de Ciências da Natureza  \
# 18                                      489.631863
# 22                                      484.889184
# 23                                      488.408591
# 24                                      488.628185
#
# ...

# %%
amp_inscritos_sudeste = np.max(sudeste['Quantidade de Inscritos']) - np.min(sudeste['Quantidade de Inscritos'])
amp_inscritos_sudeste
# Out:
# 194004

# %%
norte = pd.read_excel('enem2019.xlsx')
for i in range(norte['COD UF'].count()):
    if ((norte.loc[i]['COD UF'] // 10) != 1):
        norte = norte.drop([i], axis=0)
norte
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 1       16     AP                     6136
# 3       13     AM                    25817
# 6       15     PA                    46742
# 11      17     TO                     9087
# 17      12     AC                     5330
# 20      14     RR                     2203
# 21      11     RO                    12069
#
#     Total de inscritos de Ensino Médio Público  \
# 1                                         5711
# 3                                        24541
# 6                                        42100
# 11                                        8627
# 17                                        5054
# 20                                        2030
# 21                                       11681
#
#     Total de inscritos de Ensino Médio Privado  \
# 1                                          425
# 3                                         1276
# 6                                         4642
# ...

# %%
amp_inscritos_norte = np.max(norte['Quantidade de Inscritos']) - np.min(norte['Quantidade de Inscritos'])
amp_inscritos_norte
# Out:
# 44539

# %%
sul = pd.read_excel('enem2019.xlsx')
for i in range(sul['COD UF'].count()):
    if ((sul.loc[i]['COD UF'] // 10) != 4):
        sul = sul.drop([i], axis=0)
sul
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 0       43     RS                    46173
# 10      42     SC                    34646
# 16      41     PR                    52788
#
#     Total de inscritos de Ensino Médio Público  \
# 0                                        41424
# 10                                       30937
# 16                                       46058
#
#     Total de inscritos de Ensino Médio Privado  \
# 0                                         4749
# 10                                        3709
# 16                                        6730
#
#     Média da nota da prova de Ciências da Natureza  \
# 0                                       484.659842
# 10                                      488.451978
# 16                                      487.354390
#
#     Média da nota da prova de Ciências Humanas  \
# 0                                   524.267227
# 10                                  522.626599
# ...

# %%
x = amp_inscritos_sudeste - amp_inscritos_norte

# %%
y = pd.Series(sul['Total de inscritos de Ensino Médio Público']).mad()

# %%
(x, y)
# Out:
# (149465, 5690.666666666667)

# %%
#Questão 2
import numpy as np
import pandas as pd

arquivoEnem = pd.read_excel('enem2019.xlsx')
arqEnemAntigo = arquivoEnem
arquivoEnem
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 0       43     RS                    46173
# 1       16     AP                     6136
# 2       27     AL                    17551
# 3       13     AM                    25817
# 4       52     GO                    35546
# 5       53     DF                    21075
# 6       15     PA                    46742
# 7       26     PE                    61506
# 8       22     PI                    24156
# 9       28     SE                    13494
# 10      42     SC                    34646
# 11      17     TO                     9087
# 12      51     MT                    18022
# 13      25     PB                    26938
# 14      21     MA                    43497
# 15      24     RN                    20349
# 16      41     PR                    52788
# 17      12     AC                     5330
# 18      33     RJ                    73086
# 19      23     CE                   112313
# 20      14     RR                     2203
# ...

# %%
percentual = arquivoEnem['Total de inscritos de Ensino Médio Privado'].sum() / arquivoEnem['Quantidade de Inscritos'].sum()
percent = percentual * 100
percent
# Out:
# 11.4655415840169

# %%
quoc_variancia = pd.Series(arquivoEnem['Total de inscritos de Ensino Médio Público']).var() / pd.Series(arquivoEnem['Total de inscritos de Ensino Médio Privado']).var()
quoc_variancia
# Out:
# 34.47957929225894

# %%
(percent, quoc_variancia)
# Out:
# (11.4655415840169, 34.47957929225894)

# %%
#Questão 3
nordeste = pd.read_excel('enem2019.xlsx')
for i in range(nordeste['COD UF'].count()):
    if ((nordeste.loc[i]['COD UF'] // 10) != 2):
        nordeste = nordeste.drop([i], axis=0)
nordeste
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 2       27     AL                    17551
# 7       26     PE                    61506
# 8       22     PI                    24156
# 9       28     SE                    13494
# 13      25     PB                    26938
# 14      21     MA                    43497
# 15      24     RN                    20349
# 19      23     CE                   112313
# 26      29     BA                    70328
#
#     Total de inscritos de Ensino Médio Público  \
# 2                                        15328
# 7                                        55191
# 8                                        21457
# 9                                        11261
# 13                                       23442
# 14                                       41377
# 15                                       17686
# 19                                      106275
# 26                                       62827
#
# ...

# %%
sudeste = pd.read_excel('enem2019.xlsx')
for i in range(sudeste['COD UF'].count()):
    if ((sudeste.loc[i]['COD UF'] // 10) != 3):
        sudeste = sudeste.drop([i], axis=0)
sudeste
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 18      33     RJ                    73086
# 22      32     ES                    25422
# 23      31     MG                   108173
# 24      35     SP                   219426
#
#     Total de inscritos de Ensino Médio Público  \
# 18                                       58065
# 22                                       23187
# 23                                       97493
# 24                                      185540
#
#     Total de inscritos de Ensino Médio Privado  \
# 18                                       15021
# 22                                        2235
# 23                                       10680
# 24                                       33886
#
#     Média da nota da prova de Ciências da Natureza  \
# 18                                      489.631863
# 22                                      484.889184
# 23                                      488.408591
# 24                                      488.628185
#
# ...

# %%
norte = pd.read_excel('enem2019.xlsx')
for i in range(norte['COD UF'].count()):
    if ((norte.loc[i]['COD UF'] // 10) != 1):
        norte = norte.drop([i], axis=0)
norte
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 1       16     AP                     6136
# 3       13     AM                    25817
# 6       15     PA                    46742
# 11      17     TO                     9087
# 17      12     AC                     5330
# 20      14     RR                     2203
# 21      11     RO                    12069
#
#     Total de inscritos de Ensino Médio Público  \
# 1                                         5711
# 3                                        24541
# 6                                        42100
# 11                                        8627
# 17                                        5054
# 20                                        2030
# 21                                       11681
#
#     Total de inscritos de Ensino Médio Privado  \
# 1                                          425
# 3                                         1276
# 6                                         4642
# ...

# %%
sul = pd.read_excel('enem2019.xlsx')
for i in range(sul['COD UF'].count()):
    if ((sul.loc[i]['COD UF'] // 10) != 4):
        sul = sul.drop([i], axis=0)
sul
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 0       43     RS                    46173
# 10      42     SC                    34646
# 16      41     PR                    52788
#
#     Total de inscritos de Ensino Médio Público  \
# 0                                        41424
# 10                                       30937
# 16                                       46058
#
#     Total de inscritos de Ensino Médio Privado  \
# 0                                         4749
# 10                                        3709
# 16                                        6730
#
#     Média da nota da prova de Ciências da Natureza  \
# 0                                       484.659842
# 10                                      488.451978
# 16                                      487.354390
#
#     Média da nota da prova de Ciências Humanas  \
# 0                                   524.267227
# 10                                  522.626599
# ...

# %%
centroeste = pd.read_excel('enem2019.xlsx')
for i in range(centroeste['COD UF'].count()):
    if ((centroeste.loc[i]['COD UF'] // 10) != 5):
        centroeste = centroeste.drop([i], axis=0)
centroeste
# Out:
#     COD UF Estado  Quantidade de Inscritos  \
# 4       52     GO                    35546
# 5       53     DF                    21075
# 12      51     MT                    18022
# 25      50     MS                    15539
#
#     Total de inscritos de Ensino Médio Público  \
# 4                                        31323
# 5                                        16488
# 12                                       16515
# 25                                       14237
#
#     Total de inscritos de Ensino Médio Privado  \
# 4                                         4223
# 5                                         4587
# 12                                        1507
# 25                                        1302
#
#     Média da nota da prova de Ciências da Natureza  \
# 4                                       477.625078
# 5                                       491.416323
# 12                                      465.892259
# 25                                      473.982698
#
# ...

# %%
nordeste_disciplinas = nordeste.drop(['COD UF', 'Quantidade de Inscritos', 'Total de inscritos de Ensino Médio Público', 'Total de inscritos de Ensino Médio Privado'], axis=1)
df_nordeste_disciplinas = pd.DataFrame(nordeste_disciplinas)
df_nordeste_disciplinas
# Out:
#    Estado  Média da nota da prova de Ciências da Natureza  \
# 2      AL                                      453.600683
# 7      PE                                      464.062071
# 8      PI                                      458.422668
# 9      SE                                      464.918482
# 13     PB                                      463.969121
# 14     MA                                      443.420893
# 15     RN                                      475.937653
# 19     CE                                      451.870939
# 26     BA                                      462.197014
#
#     Média da nota da prova de Ciências Humanas  \
# 2                                   480.601937
# 7                                   491.227411
# 8                                   482.635566
# 9                                   491.793049
# 13                                  491.600768
# 14                                  469.198684
# 15                                  502.031469
# ...

# %%
media_geral_por_estado_nordeste = df_nordeste_disciplinas.mean(axis=0)
media_geral_por_estado_nordeste
# Out:
# Média da nota da prova de Ciências da Natureza    459.822169
# Média da nota da prova de Ciências Humanas        486.437270
# Média da nota da prova de Linguagens e Códigos    501.290674
# Média da nota da prova de Matemática              504.269135
# Média da nota da prova de redação                 565.778561
# dtype: float64

# %%
desvio_padrao_nordeste = pd.Series(media_geral_por_estado_nordeste).std()
desvio_padrao_nordeste
# Out:
# 38.996729407301984

# %%
sudeste_disciplinas = sudeste.drop(['COD UF', 'Quantidade de Inscritos', 'Total de inscritos de Ensino Médio Público', 'Total de inscritos de Ensino Médio Privado'], axis=1)
df_sudeste_disciplinas = pd.DataFrame(sudeste_disciplinas)
df_sudeste_disciplinas
# Out:
#    Estado  Média da nota da prova de Ciências da Natureza  \
# 18     RJ                                      489.631863
# 22     ES                                      484.889184
# 23     MG                                      488.408591
# 24     SP                                      488.628185
#
#     Média da nota da prova de Ciências Humanas  \
# 18                                  519.930533
# 22                                  512.252211
# 23                                  516.265989
# 24                                  521.312772
#
#     Média da nota da prova de Linguagens e Códigos  \
# 18                                      533.396993
# 22                                      521.987041
# 23                                      527.469714
# 24                                      535.519439
#
#     Média da nota da prova de Matemática  Média da nota da prova de redação
# 18                            541.914833                         605.732021
# ...

# %%
media_geral_por_estado_sudeste = df_sudeste_disciplinas.mean(axis=0)
media_geral_por_estado_sudeste
# Out:
# Média da nota da prova de Ciências da Natureza    487.889456
# Média da nota da prova de Ciências Humanas        517.440376
# Média da nota da prova de Linguagens e Códigos    529.593297
# Média da nota da prova de Matemática              544.992793
# Média da nota da prova de redação                 598.633811
# dtype: float64

# %%
desvio_padrao_sudeste = pd.Series(media_geral_por_estado_sudeste).std()
desvio_padrao_sudeste
# Out:
# 40.9376779462644

# %%
norte_disciplinas = norte.drop(['COD UF', 'Quantidade de Inscritos', 'Total de inscritos de Ensino Médio Público', 'Total de inscritos de Ensino Médio Privado'], axis=1)
df_norte_disciplinas = pd.DataFrame(norte_disciplinas)
df_norte_disciplinas
# Out:
#    Estado  Média da nota da prova de Ciências da Natureza  \
# 1      AP                                      446.884217
# 3      AM                                      446.577429
# 6      PA                                      454.386761
# 11     TO                                      455.306262
# 17     AC                                      454.615066
# 20     RR                                      464.764538
# 21     RO                                      458.499847
#
#     Média da nota da prova de Ciências Humanas  \
# 1                                   477.089716
# 3                                   475.833558
# 6                                   481.895274
# 11                                  478.853000
# 17                                  482.340857
# 20                                  493.750264
# 21                                  485.541271
#
#     Média da nota da prova de Linguagens e Códigos  \
# 1                                       491.826222
# ...

# %%
media_geral_por_estado_norte = df_norte_disciplinas.mean(axis=0)
media_geral_por_estado_norte
# Out:
# Média da nota da prova de Ciências da Natureza    454.433446
# Média da nota da prova de Ciências Humanas        482.186277
# Média da nota da prova de Linguagens e Códigos    498.047329
# Média da nota da prova de Matemática              491.570353
# Média da nota da prova de redação                 542.626425
# dtype: float64

# %%
desvio_padrao_norte = pd.Series(media_geral_por_estado_norte).std()
desvio_padrao_norte
# Out:
# 31.98293059295579

# %%
sul_disciplinas = sul.drop(['COD UF', 'Quantidade de Inscritos', 'Total de inscritos de Ensino Médio Público', 'Total de inscritos de Ensino Médio Privado'], axis=1)
df_sul_disciplinas = pd.DataFrame(sul_disciplinas)
df_sul_disciplinas
# Out:
#    Estado  Média da nota da prova de Ciências da Natureza  \
# 0      RS                                      484.659842
# 10     SC                                      488.451978
# 16     PR                                      487.354390
#
#     Média da nota da prova de Ciências Humanas  \
# 0                                   524.267227
# 10                                  522.626599
# 16                                  519.390627
#
#     Média da nota da prova de Linguagens e Códigos  \
# 0                                       533.906006
# 10                                      531.496343
# 16                                      529.712041
#
#     Média da nota da prova de Matemática  Média da nota da prova de redação
# 0                             546.707112                         598.457500
# 10                            548.319166                         587.808690
# 16                            541.746659                         570.283666

# %%
media_geral_por_estado_sul = df_sul_disciplinas.mean(axis=0)
media_geral_por_estado_sul
# Out:
# Média da nota da prova de Ciências da Natureza    486.822070
# Média da nota da prova de Ciências Humanas        522.094818
# Média da nota da prova de Linguagens e Códigos    531.704797
# Média da nota da prova de Matemática              545.590979
# Média da nota da prova de redação                 585.516619
# dtype: float64

# %%
desvio_padrao_sul = pd.Series(media_geral_por_estado_sul).std()
desvio_padrao_sul
# Out:
# 35.91821653340987

# %%
centroeste_disciplinas = centroeste.drop(['COD UF', 'Quantidade de Inscritos', 'Total de inscritos de Ensino Médio Público', 'Total de inscritos de Ensino Médio Privado'], axis=1)
df_centroeste_disciplinas = pd.DataFrame(centroeste_disciplinas)
df_centroeste_disciplinas
# Out:
#    Estado  Média da nota da prova de Ciências da Natureza  \
# 4      GO                                      477.625078
# 5      DF                                      491.416323
# 12     MT                                      465.892259
# 25     MS                                      473.982698
#
#     Média da nota da prova de Ciências Humanas  \
# 4                                   505.805269
# 5                                   521.916533
# 12                                  493.876876
# 25                                  501.326601
#
#     Média da nota da prova de Linguagens e Códigos  \
# 4                                       520.101327
# 5                                       537.273155
# 12                                      506.193957
# 25                                      517.284766
#
#     Média da nota da prova de Matemática  Média da nota da prova de redação
# 4                             528.496087                         594.747233
# ...

# %%
media_geral_por_estado_centroeste = df_centroeste_disciplinas.mean(axis=0)
media_geral_por_estado_centroeste
# Out:
# Média da nota da prova de Ciências da Natureza    477.229090
# Média da nota da prova de Ciências Humanas        505.731320
# Média da nota da prova de Linguagens e Códigos    520.213301
# Média da nota da prova de Matemática              524.339688
# Média da nota da prova de redação                 583.111094
# dtype: float64

# %%
desvio_padrao_centroeste = pd.Series(media_geral_por_estado_centroeste).std()
desvio_padrao_centroeste
# Out:
# 38.76937781615135

# %%
desvio_padrao = {'Desvio Padrão' :[desvio_padrao_nordeste, desvio_padrao_sudeste, desvio_padrao_norte, desvio_padrao_sul, desvio_padrao_centroeste]}
desvio_padrao
# Out:
# {'Desvio Padrão': [38.996729407301984,
#   40.9376779462644,
#   31.98293059295579,
#   35.91821653340987,
#   38.76937781615135]}

# %%
df_desvio_padrao_regioes = pd.DataFrame(desvio_padrao, index=['Nordeste', 'Sudeste', 'Norte', 'Sul', 'Centro-oeste'])
df_desvio_padrao_regioes
# Out:
#               Desvio Padrão
# Nordeste          38.996729
# Sudeste           40.937678
# Norte             31.982931
# Sul               35.918217
# Centro-oeste      38.769378

# %%
df_desvio_padrao_regioes.sort_values(by='Desvio Padrão', ascending=False)
# Out:
#               Desvio Padrão
# Sudeste           40.937678
# Nordeste          38.996729
# Centro-oeste      38.769378
# Sul               35.918217
# Norte             31.982931

# %%
df_desvio_padrao_regioes.sort_values(by='Desvio Padrão', ascending=False).head(2)
# Out:
#           Desvio Padrão
# Sudeste       40.937678
# Nordeste      38.996729
